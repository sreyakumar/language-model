# %%
import requests
import re

# %%
r = requests.get('https://www.informatics.jax.org/marker/MGI:95634')

# %%
r.content
# Out:
# b'\n\n\n\n\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "https://www.w3.org/TR/html4/loose.dtd">\n\n<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n\n\n<!-- Google tag (gtag.js) -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-8D61GHC97X"></script>\n<script>\n  var c = document.cookie.split(\'; \').filter(c => c.startsWith(\'mgi_user_consent=\'))[0]\n  if (!c || c === "mgi_user_consent=analytics") {\n      window.dataLayer = window.dataLayer || [];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'js\', new Date());\n      gtag(\'config\', \'G-8D61GHC97X\');\n      console.log("GA4 ok")\n  } else {\n      console.log("GA4 blocked")\n  }\n</script>\n\n\n\n<!-- Combo-handled YUI JS files: -->\n<script type="text/javascript" src="https://www.informatics.jax.org/webshare/js/yui-2.8.custom.min.js"></script>\n\n<!-- jQuery -->\n<script type="text/javascript" src="https://www.informatics.jax.org/we
# ...
